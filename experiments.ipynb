# %%
# Load the data into variables for experimentation
job_description_path = "api/experiments/job_description.txt"
pdf_text_path = "api/experiments/pdf_text.txt"

try:
    with open(job_description_path, 'r', encoding="utf-8") as f:
        job_text = f.read()

    with open(pdf_text_path, 'r', encoding="utf-8") as f:
        cv_text = f.read()
        
    print("✅ Files loaded successfully!")
    print(f"Job Description length: {len(job_text)} characters")
    print(f"CV Text length: {len(cv_text)} characters")

except FileNotFoundError:
    print("❌ Error: Files not found. Make sure you ran the Django view first!")
# Out:
# ✅ Files loaded successfully!
# Job Description length: 2694 characters
# CV Text length: 4082 characters

# %%
job_text
# Out:
# "Product Manager (Games domain)\n- Product\n- Tel Aviv\n- Mid\n- Full-time\nDescription\nTango is a successful, market leader, a live-streaming Platform with 550+ million registered users, in an industry projected to reach $240 BILLION in the next couple of years.\nThe B2C platform, based on the best-quality global video technology, allows millions of talented people around the world to create their own live content, engage with their fans, and monetize their talents.\nTango live stream was founded in 2018 and is powered by 500+ global employees operating in a culture of growth, learning, and success!\nThe Tango team is a vigorous cocktail of hard workers, creative brains, energizers, geeks, overachievers, athletes, and more. We push the limits to bring our app from “one of the top” to “the leader”.\nThe best way to describe Tango's work style is not to use the word “impossible”. And we believe that success is a thorny path that runs on sleepless nights, corporate parties, tough rele
# ...

# %%
cv_text
# Out:
# 'Dor Lazarov\nProduct Manager with 4 years of experience\nLazamal@gmail.com\nhttps://www.linkedin.com/in/dor-lazarov-65601287\nMy Product portfolio\nTel-Aviv, Israel\n054-9732735\nSUMMARY\nProduct Manager with over 4 years of experience leading web and mobile application products in EdTech and SportTech. Skilled at working cross-\nfunctionally with developers, designers, and stakeholders to deliver user-centered products in resource-constrained environments. \nStrong background in educational and youth-focused organizations, bringing a mission-driven mindset and a hands-on approach to agile\ndevelopment. \nLooking for product management roles in a fast pace start-up company\nEXPERIENCE\nDrorsoft - Coding Your Dreams\nProduct Manager\n2025 - present\nTel-Aviv\nProduct:\nLed the product launch, development, and specification of a personal management\nsystem commissioned by a company client.\nEliminating the need for outsourced services and generating annual savings of over ₪10,000\nfor
# ...

# %%
import re
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\lazam\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
en_stopwords = stopwords.words('english')
print(en_stopwords)
# Out:
# ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't", 'as', 'at', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both', 'but', 'by', 'can', 'couldn', "couldn't", 'd', 'did', 'didn', "didn't", 'do', 'does', 'doesn', "doesn't", 'doing', 'don', "don't", 'down', 'during', 'each', 'few', 'for', 'from', 'further', 'had', 'hadn', "hadn't", 'has', 'hasn', "hasn't", 'have', 'haven', "haven't", 'having', 'he', "he'd", "he'll", 'her', 'here', 'hers', 'herself', "he's", 'him', 'himself', 'his', 'how', 'i', "i'd", 'if', "i'll", "i'm", 'in', 'into', 'is', 'isn', "isn't", 'it', "it'd", "it'll", "it's", 'its', 'itself', "i've", 'just', 'll', 'm', 'ma', 'me', 'mightn', "mightn't", 'more', 'most', 'mustn', "mustn't", 'my', 'myself', 'needn', "needn't", 'no', 'nor', 'not', 'now', 'o', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 're', 's', 'same', 'shan', "shan't", 's
# ...

# %%
job_text_no_stopwords = " ".join([word.lower() for word in job_text.split() if word not in en_stopwords])
job_text_no_stopwords
# Out:
# "product manager (games domain) - product - tel aviv - mid - full-time description tango successful, market leader, live-streaming platform 550+ million registered users, industry projected reach $240 billion next couple years. the b2c platform, based best-quality global video technology, allows millions talented people around world create live content, engage fans, monetize talents. tango live stream founded 2018 powered 500+ global employees operating culture growth, learning, success! the tango team vigorous cocktail hard workers, creative brains, energizers, geeks, overachievers, athletes, more. we push limits bring app “one top” “the leader”. the best way describe tango's work style use word “impossible”. and believe success thorny path runs sleepless nights, corporate parties, tough releases, and, course, users' smiles (and live app, truly get see users around world smiling right front us real-time!). do want join party? we’re looking product manager (games domain) join product
# ...

# %%
cv_text_no_stopwords = " ".join([word.lower() for word in cv_text.split() if word not in en_stopwords])
cv_text_no_stopwords
# Out:
# 'dor lazarov product manager 4 years experience lazamal@gmail.com https://www.linkedin.com/in/dor-lazarov-65601287 my product portfolio tel-aviv, israel 054-9732735 summary product manager 4 years experience leading web mobile application products edtech sporttech. skilled working cross- functionally developers, designers, stakeholders deliver user-centered products resource-constrained environments. strong background educational youth-focused organizations, bringing mission-driven mindset hands-on approach agile development. looking product management roles fast pace start-up company experience drorsoft - coding your dreams product manager 2025 - present tel-aviv product: led product launch, development, specification personal management system commissioned company client. eliminating need outsourced services generating annual savings ₪10,000 client. conducted in-depth user behavior analysis research, resulting 30% improvement workflow efficiency higher tool adoption across departme
# ...
